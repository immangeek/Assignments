# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Assignment5

# %% [markdown]
# ## Ground Cricket Chirps
#
# In _The Song of Insects_ (1948) by George W. Pierce, Pierce mechanically measured the frequency (the number of wing vibrations per second) of chirps (or pulses of sound) made by a striped ground cricket, at various ground temperatures.  Since crickets are ectotherms (cold-blooded), the rate of their physiological processes and their overall metabolism are influenced by temperature.  Consequently, there is reason to believe that temperature would have a profound effect on aspects of their behavior, such as chirp frequency.
#
# In general, it was found that crickets did not sing at temperatures colder than 60º F. or warmer than 100º F.

# %%
ground_cricket_data = {"Chirps/Second": [20.0, 16.0, 19.8, 18.4, 17.1, 15.5, 14.7,
                                         15.7, 15.4, 16.3, 15.0, 17.2, 16.0, 17.0,
                                         14.4],
                       "Ground Temperature": [88.6, 71.6, 93.3, 84.3, 80.6, 75.2, 69.7,
                                              71.6, 69.4, 83.3, 79.6, 82.6, 80.6, 83.5,
                                              76.3]}
df = pd.DataFrame(ground_cricket_data)

# %%
df.head(5)
# Out:
#    Chirps/Second  Ground Temperature
# 0           20.0                88.6
# 1           16.0                71.6
# 2           19.8                93.3
# 3           18.4                84.3
# 4           17.1                80.6

# %%
x = df['Chirps/Second']
y = df['Ground Temperature']

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
c=model.intercept_
print('m value is ',c)
m= model.coef_
print("c value is ",m)
# Out:
# m value is  22.848982308066887
# c value is  [3.410323]

# %%
print("The equation of linear regresssion is ",m,'x+',c)
# Out:
# The equation of linear regresssion is  [3.410323] x+ 22.848982308066887

# %%
#plt.figure(figsize=(10,10))

plt.plot(x,y,'o')
plt.plot(x,model.predict(X))

# %%
score = model.score(X,Y)*100
print("The score is ",score)
# Out:
# The score is  69.22946529147002

# %%
#x=(1-c)/m[95] 
chirping = (95-c)/m
print("4) Approximate rate would expect the crickets to be chirping is ",chirping)
# Out:
# 4) Approximate rate would expect the crickets to be chirping is  [21.15665223]

# %%
temperature = model.predict([[18]])
print("5) approximate ground temperature that morning was ",temperature)
# Out:
# 5) approximate ground temperature that morning was  [84.2347963]
# /home/imman/.local/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Tasks
#
# 1. Find the linear regression equation for this data.
# 2. Chart the original data and the equation on the chart.
# 3. Find the equation's $R^2$ score (use the `.score` method) to determine whether the
# equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)
# 4. Extrapolate data:  If the ground temperature reached 95, then at what approximate rate would you expect the crickets to be chirping?
# 5. Interpolate data:  With a listening device, you discovered that on a particular morning the crickets were chirping at a rate of 18 chirps per second.  What was the approximate ground temperature that morning?

# %% [markdown]
# # Assignment6

# %% [markdown]
# ## Brain vs. Body Weight
#
# In the file `brain_body.txt`, the average brain and body weight for a number of mammal species are recorded. Load this data into a Pandas data frame.
#
# ### Tasks
#
# 1. Find the linear regression equation for this data for brain weight to body weight.
# 2. Chart the original data and the equation on the chart.
# 3. Find the equation's $R^2$ score (use the `.score` method) to determine whether the
# equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)

# %%
df = pd.read_fwf("brain_body.txt")

# %%
df
# Out:
#       Brain   Body
# 0     3.385   44.5
# 1     0.480   15.5
# 2     1.350    8.1
# 3   465.000  423.0
# 4    36.330  119.5
# ..      ...    ...
# 57  160.000  169.0
# 58    0.900    2.6
# 59    1.620   11.4
# 60    0.104    2.5
# 61    4.235   50.4
#
# [62 rows x 2 columns]

# %%
model = LinearRegression()

# %%
X = df[['Brain']]
x =df['Brain']
Y= df['Body']

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
m = model.coef_
c = model.intercept_
print("1) Equation of the regression is ",m,'x+',c)
# Out:
# 1) Equation of the regression is  [0.96649637] x+ 91.00439620740687

# %%
plt.plot(x,Y,'o')
plt.plot(x,model.predict(X))

# %%
score = model.score(X,Y)*100
print("3) Score is ",score)
# Out:
# 3) Score is  87.26620843043331

# %% [markdown]
# # Assignment7

# %% [markdown]
# ## Salary Discrimination
#
# The file `salary.txt` contains data for 52 tenure-track professors at a small Midwestern college. This data was used in legal proceedings in the 1980s about discrimination against women in salary.
#
# The data in the file, by column:
#
# 1. Sex. 1 for female, 0 for male.
# 2. Rank. 1 for assistant professor, 2 for associate professor, 3 for full professor.
# 3. Year. Number of years in current rank.
# 4. Degree. Highest degree. 1 for doctorate, 0 for master's.
# 5. YSdeg. Years since highest degree was earned.
# 6. Salary. Salary/year in dollars.
#
# ### Tasks
#
# 1. Find the linear regression equation for this data using columns 1-5 to column 6.
# 2. Find the selection of columns with the best $R^2$ score.
# 3. Report whether sex is a factor in salary.

# %%
df = pd.read_fwf("salary.txt", header=None, 
                 names=["Sex", "Rank", "Year", "Degree", "YSdeg", "Salary"])

# %%
df.head()
# Out:
#    Sex  Rank  Year  Degree  YSdeg  Salary
# 0    0     3    25       1     35   36350
# 1    0     3    13       1     22   35350
# 2    0     3    10       1     23   28200
# 3    1     3     7       1     27   26775
# 4    0     3    19       0     30   33696

# %%
x1 = df[['Sex']]
x2 = df[['Rank']]
x3 = df[['Year']]
x4 = df[['Degree']]
x5 = df[['YSdeg']]

y = df['Salary']

# %%
model.fit(x1,y1)
sex_score = model.score(x1,y1)*100
print("Sex vs Salary Score is ",sex_score)
# Out:
# Sex vs Salary Score is  6.389892583288004

# %%
model.fit(x2,y1)
rank_score = model.score(x2,y1)*100
print("rank vs Salary Score is ",rank_score)
# Out:
# rank vs Salary Score is  75.25360539274632

# %%
model.fit(x3,y1)
year_score = model.score(x3,y1)*100
print("Year vs Salary Score is ",year_score)
# Out:
# rank vs Salary Score is  49.09370267692162

# %%
model.fit(x4,y1)
degree_score = model.score(x4,y1)*100
print("Degree vs Salary Score is ",degree_score)
# Out:
# Degree vs Salary Score is  0.48616809847483733

# %%
model.fit(x5,y1)
years_score = model.score(x5,y1)*100
print("Degree vs Salary Score is ",years_score)
# Out:
# Degree vs Salary Score is  45.54281345836028

# %%
print("4) Rank is affecting the salary most",rank_score)
# Out:
# 4) Rank is affecting the salary most 75.25360539274632

# %% [markdown]
# ### 3) Sex is not affecting the salary bcoz that's score is very low
